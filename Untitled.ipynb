# %%
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

API_KEY = 'RGAPI-8a7fa3f5-2f07-4653-bd12-90cce6e1daa2'
REGION = 'americas'
MATCH_ID = 'BR1_2977976746'

# Fetch match timeline data
url = f"https://{REGION}.api.riotgames.com/lol/match/v5/matches/{MATCH_ID}/timeline?api_key={API_KEY}"
response = requests.get(url)
timeline = response.json()

# %%
import requests

def get_match_timeline(api_key, match_id, region='na1'):
    url = f"https://{region}.api.riotgames.com/lol/match/v5/matches/{match_id}/timeline"
    headers = {
        "X-Riot-Token": api_key
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# Example usage:
api_key = 'RGAPI-8a7fa3f5-2f07-4653-bd12-90cce6e1daa2'
match_id = 'BR1_2977976746'
timeline_data = get_match_timeline(api_key, match_id)

if timeline_data:
    print(timeline_data)
else:
    print("Failed to retrieve data.")
# Out:
# Failed to retrieve data.

# %%
def get_jungler_positions(timeline, jungler_id):
    jungler_positions = []

    for frame in timeline['info']['frames']:
        for event in frame['events']:
            if event['type'] == 'CHAMPION_KILL' and event['killerId'] == jungler_id:
                position = event['position']
                jungler_positions.append((position['x'], position['y']))

    return np.array(jungler_positions)

# Assume jungler_id is known
jungler_id = 1  # Replace with actual jungler ID
positions = get_jungler_positions(timeline, jungler_id)

# %%
# Create a 2D histogram of the positions
heatmap, xedges, yedges = np.histogram2d(positions[:, 0], positions[:, 1], bins=30)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap.T, square=True, cmap='viridis', cbar=True)
plt.title('Heat Map of Jungler Positions')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.show()

# %%
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Fetch match timeline data
url = f"https://{REGION}.api.riotgames.com/lol/match/v5/matches/{MATCH_ID}/timeline?api_key={API_KEY}"
response = requests.get(url)
timeline = response.json()

def get_jungler_positions(timeline, jungler_id):
    jungler_positions = []

    for frame in timeline['info']['frames']:
        for event in frame['events']:
            if event['type'] == 'CHAMPION_KILL' and event['killerId'] == jungler_id:
                position = event['position']
                jungler_positions.append((position['x'], position['y']))

    return np.array(jungler_positions)

# Assume jungler_id is known
jungler_id = 1  # Replace with actual jungler ID
positions = get_jungler_positions(timeline, jungler_id)

# Create a 2D histogram of the positions
heatmap, xedges, yedges = np.histogram2d(positions[:, 0], positions[:, 1], bins=30)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap.T, square=True, cmap='viridis', cbar=True)
plt.title('Heat Map of Jungler Positions')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [37], in <cell line: 26>()
#      24 # Assume jungler_id is known
#      25 jungler_id = 1  # Replace with actual jungler ID
# ---> 26 positions = get_jungler_positions(timeline, jungler_id)
#      28 # Create a 2D histogram of the positions
#      29 heatmap, xedges, yedges = np.histogram2d(positions[:, 0], positions[:, 1], bins=30)
#
# Input In [37], in get_jungler_positions(timeline, jungler_id)
#      13 def get_jungler_positions(timeline, jungler_id):
#      14     jungler_positions = []
# ---> 16     for frame in timeline['info']['frames']:
#      17         for event in frame['events']:
#      18             if event['type'] == 'CHAMPION_KILL' and event['killerId'] == jungler_id:
#
# KeyError: 'info'

# %%
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Fetch match timeline data
url = f"https://{REGION}.api.riotgames.com/lol/match/v5/matches/{MATCH_ID}/timeline?api_key={API_KEY}"
response = requests.get(url)
timeline = response.json()

def get_jungler_positions(timeline, jungler_id, start_minute, end_minute):
    jungler_positions = []
    frames = timeline['info']['frames']

    # Iterate over the frames from start_minute to end_minute
    for frame in frames:
        if frame['timestamp'] >= start_minute * 60000 and frame['timestamp'] <= end_minute * 60000:
            for event in frame['events']:
                if event['type'] == 'CHAMPION_KILL' and event['killerId'] == jungler_id:
                    position = event['position']
                    jungler_positions.append((position['x'], position['y']))

    return np.array(jungler_positions)

# Assume jungler_id is known
jungler_id = 1  # Replace with actual jungler ID
positions = get_jungler_positions(timeline, jungler_id, 2, 15)

# Create a 2D histogram of the positions
heatmap, xedges, yedges = np.histogram2d(positions[:, 0], positions[:, 1], bins=30)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap.T, square=True, cmap='viridis', cbar=True)
plt.title('Heat Map of Jungler Positions (Minutes 2-15)')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.show()

# %%
path = "D:\Furia2\summoners_rift.png"

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# Path to the minimap image
minimap_image_path = 'D:\Furia2\summoners_rift.PNG'

# Function to plot the minimap as background
def get_minimap():
    return plt.imread(minimap_image_path)

# Simulate some jungler positions data
positions = np.array([[5500, 6000], [7000, 8000], [8500, 9000], [4000, 4500]])

# Create the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Load and display the minimap image
minimap_img = get_minimap()
ax.imshow(minimap_img, extent=[0, 15000, 0, 15000], aspect='auto')

# Plot the jungler positions
x, y = positions[:, 0], positions[:, 1]
ax.scatter(x, y, c='red', s=50, edgecolors='black')

# Set the axis limits to match the minimap
ax.set_xlim(0, 15000)
ax.set_ylim(0, 15000)

# Set labels
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_title('Jungler Positions on Summoner\'s Rift Minimap')

plt.show()
# Out:
# Traceback (most recent call last):
#
#   File D:\python\program\lib\site-packages\IPython\core\interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [39] in <cell line: 19>
#     minimap_img = get_minimap()
#
#   Input In [39] in get_minimap
#     return plt.imread(minimap_image_path)
#
#   File D:\python\program\lib\site-packages\matplotlib\pyplot.py:2111 in imread
#     return matplotlib.image.imread(fname, format)
#
#   File D:\python\program\lib\site-packages\matplotlib\image.py:1541 in imread
#     with img_open(fname) as image:
#
#   File D:\python\program\lib\site-packages\PIL\ImageFile.py:116 in __init__
#     self._open()
#
#   File D:\python\program\lib\site-packages\PIL\PngImagePlugin.py:712 in _open
#     raise SyntaxError("not a PNG file")
#
#   File <string>
# SyntaxError: not a PNG file

# %%
from matplotlib.cbook import get_sample_data
minimap_image_path = get_sample_data('axes_grid/bivariate_normal.png', asfileobj=False)

# %%
# Path to the minimap image
minimap_image_path = 'D:\Furia2\summoners_rift.png'

# Function to plot the minimap as background
def get_minimap():
    return plt.imread(minimap_image_path)

get_minimap()
# Out:
# Traceback (most recent call last):
#
#   File D:\python\program\lib\site-packages\IPython\core\interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [41] in <cell line: 8>
#     get_minimap()
#
#   Input In [41] in get_minimap
#     return plt.imread(minimap_image_path)
#
#   File D:\python\program\lib\site-packages\matplotlib\pyplot.py:2111 in imread
#     return matplotlib.image.imread(fname, format)
#
#   File D:\python\program\lib\site-packages\matplotlib\image.py:1541 in imread
#     with img_open(fname) as image:
#
#   File D:\python\program\lib\site-packages\PIL\ImageFile.py:116 in __init__
#     self._open()
#
#   File D:\python\program\lib\site-packages\PIL\PngImagePlugin.py:712 in _open
#     raise SyntaxError("not a PNG file")
#
#   File <string>
# SyntaxError: not a PNG file

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# Load the minimap image
minimap_image_path = 'D:\\Furia2\\real_summoners.jpeg'
minimap_img = mpimg.imread(minimap_image_path)

# Simulate some jungler positions data
# Example positions in the format [x, y], assuming 0 to 15000 scale
positions = np.array([
    [5500, 6000],
    [7000, 8000],
    [8500, 9000],
    [4000, 4500],
    [3000, 4000],
    [12000, 13000],
    [10000, 11000]
])

# Create the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Display the minimap image
ax.imshow(minimap_img, extent=[0, 15000, 0, 15000], aspect='auto')

# Plot the jungler positions
x, y = positions[:, 0], positions[:, 1]
ax.scatter(x, y, c='red', s=100, edgecolors='black')

# Set the axis limits to match the minimap
ax.set_xlim(0, 15000)
ax.set_ylim(0, 15000)

# Set labels
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_title('Jungler Positions on Summoner\'s Rift Minimap')

plt.show()

# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# Fetch match timeline data
url = f"https://{REGION}.api.riotgames.com/lol/match/v5/matches/{MATCH_ID}/timeline?api_key={API_KEY}"
response = requests.get(url)
timeline = response.json()

def get_jungler_positions(timeline, jungler_id, start_minute, end_minute):
    jungler_positions = []
    frames = timeline['info']['frames']

    # Iterate over the frames from start_minute to end_minute
    for frame in frames:
        if start_minute * 60000 <= frame['timestamp'] <= end_minute * 60000:
            for event in frame['events']:
                if 'position' in event and 'participantId' in event and event['participantId'] == jungler_id:
                    position = event['position']
                    jungler_positions.append((position['x'], position['y']))

    return np.array(jungler_positions)

# Assume jungler_id is known
jungler_id = 1  # Replace with actual jungler ID
positions = get_jungler_positions(timeline, jungler_id, 2, 15)

# Load the minimap image
minimap_image_path = 'D:\\Furia2\\real_summoners.jpeg'
minimap_img = mpimg.imread(minimap_image_path)

# Create the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Display the minimap image
ax.imshow(minimap_img, extent=[0, 15000, 0, 15000], aspect='auto')

# Plot the jungler positions
x, y = positions[:, 0], positions[:, 1]
ax.scatter(x, y, c='red', s=100, edgecolors='black')

# Set the axis limits to match the minimap
ax.set_xlim(0, 15000)
ax.set_ylim(0, 15000)

# Set labels
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_title('Jungler Positions on Summoner\'s Rift Minimap')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 27>()
#      25 # Assume jungler_id is known
#      26 jungler_id = 1  # Replace with actual jungler ID
# ---> 27 positions = get_jungler_positions(timeline, jungler_id, 2, 15)
#      29 # Load the minimap image
#      30 minimap_image_path = 'D:\\Furia2\\real_summoners.jpeg'
#
# Input In [43], in get_jungler_positions(timeline, jungler_id, start_minute, end_minute)
#      11 def get_jungler_positions(timeline, jungler_id, start_minute, end_minute):
#      12     jungler_positions = []
# ---> 13     frames = timeline['info']['frames']
#      15     # Iterate over the frames from start_minute to end_minute
#      16     for frame in frames:
#
# KeyError: 'info'

# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

API_KEY = 'YOUR_RIOT_API_KEY'
REGION = 'americas'
MATCH_ID = 'YOUR_MATCH_ID'
JUNGLER_ID = 1  # Replace with the actual jungler participant ID

# Fetch match timeline data
url = f"https://{REGION}.api.riotgames.com/lol/match/v5/matches/{MATCH_ID}/timeline?api_key={API_KEY}"
response = requests.get(url)
timeline = response.json()

def get_jungler_positions(timeline, jungler_id, start_minute, end_minute):
    jungler_positions = []
    frames = timeline['info']['frames']

    # Iterate over the frames from start_minute to end_minute
    for frame in frames:
        if start_minute * 60000 <= frame['timestamp'] <= end_minute * 60000:
            for event in frame['events']:
                if 'position' in event and 'participantId' in event and event['participantId'] == jungler_id:
                    position = event['position']
                    jungler_positions.append((position['x'], position['y']))

    return np.array(jungler_positions)

# Get jungler positions from minute 2 to 15
positions = get_jungler_positions(timeline, JUNGLER_ID, 2, 15)

# Load the Summoner's Rift minimap image
minimap_image_path = 'D:\\Furia2\\real_summoners.jpeg'
minimap_img = mpimg.imread(minimap_image_path)

# Create the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Display the minimap image
ax.imshow(minimap_img, extent=[0, 15000, 0, 15000], aspect='auto')

# Plot the jungler positions if any
if positions.size > 0:
    x, y = positions[:, 0], positions[:, 1]
    ax.scatter(x, y, c='red', s=100, edgecolors='black')

# Set the axis limits to match the minimap
ax.set_xlim(0, 15000)
ax.set_ylim(0, 15000)

# Set labels
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_title('Jungler Positions on Summoner\'s Rift Minimap')

plt.show()
